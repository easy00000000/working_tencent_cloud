# %% [markdown]
# ### 一、CAPM的不足与三因子模型的诞生
#
# CAPM模型经历了大量的实证和应用之后，有证据表明，市场风险溢酬并不能充分解释个别风险资产的收益率。于是很多研究者开始探索其他的因素，比如公司市值、PE、杠杆比例、账面市值比等。
#
# Fama和French两个人对于各种因素进行了全面的组合分析，当单独使用Beta或者用Beta分别与其他几个因子相结合时，Beta的解释能力很弱；市值、PE（市盈率）、杠杆比例、BM（账面市值比，PB的倒数）单独来用时，对于收益率的解释能力都很强，但是组合起来时，市值、BM会弱化杠杆比例和PE的解释能力。
#
# 后来Fama和French两人提取了3个重要因子：市场风险溢酬因子、市值因子和账面市值比因子，以收益率作为因变量构建了一个类似CAPM的线性模型，即著名的三因子模型。

# %% [markdown]
# ### 二、三因子模型的原理
#
# 三因子模型中的3个因子均为投资组合的收益率：市场风险溢酬因子对应了市场投资组合的收益率，市值因子对应了做多市值较小的公司与做空市值较大的公司的投资组合带来的收益率，账面市值比因子对应的是做多高BM公司（价值公司）、做空低BM公司（成长公司）的投资组合带来的收益率。三因子模型的形式为：
#
# $$ \begin{aligned}
# & R_{it} - R_{ft} = \alpha_{i} + \beta_{i}\cdot (R_{mt}-R_{ft}) + s_{i}\cdot SMB_{t} + h{i}\cdot HML_{t} +\varepsilon_{i} \\
# & 其中： \\
# & R_{it}：目标资产投资收益率 \\
# & R_{ft}：无风险收益率，用国债指数收益代替 \\
# & \alpha_{i}：超额收益 \\
# & R_{mt}：全市场组合投资收益率，用适合的大盘指数代替 \\
# & SMB_{t}：小市值-大市值组合投资收益率 \\
# & HML_{t}：价值-成长组合投资收益率
# \end{aligned} $$
#
# 这样大家就比较熟悉了，一个常数项，三个自变量，一个误差项，一个因变量，妥妥的一个多元线性回归模型。跟CAPM中一样，α代表超额收益率，越高越好，说明我们的投资组合越优秀。
#
# 不要看到这么多名词就害怕，在实际应用过程中，这些数据都是已知的，我们直接把数据扔给计算机，通过最小二乘法求解得到α、b、s、h的估计值即可以及它们是否显著即可。
#
# 唯一稍显麻烦一点的是SMB和HML的计算，这一部分需要先根据流通市值将股票分为1：1的大市值（B）和小市值（S)股票；根据BM数据将股票分为3：4：3的高中低（H/M/L）三组；这样我们就有了2×3共计6种投资组合（SL/SM/SH/BL/BM/BH）。然后我们通过市值加权平均的方式求得各组的收益率，最后就是求SMB和HML了：
#
# $$ \begin{aligned}
# & SMB_{t} = \frac{1}{3} \cdot (SL_{t} + SM_{t} + SH_{t}) - \frac{1}{3} \cdot (BL_{t} + BM_{t} + BH_{t}) \\
# & HML_{t} = \frac{1}{2} \cdot (SH_{t} + BH_{t}) - \frac{1}{2} \cdot (SL_{t} + BL_{t})
# \end{aligned} $$

# %% [markdown]
# ### 三、Python三因子模型选股实战
#
# #### 1、计算SMB和HML

# %%
import tushare as ts
token = '6feca07b866ea55bd6024aa5a8891d7bc11afd829d1386c8a2fc8d89'
# initial
pro = ts.pro_api(token)

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import datetime
import time
sns.set()

# %%
def cal_smb_hml(df):
    # 划分大小市值公司
    df['SB'] = df['circ_mv'].map(lambda x: 'B' if x >= df['circ_mv'].median() else 'S')

    # 求账面市值比：PB的倒数
    df['BM'] = 1 / df['pb']

    # 划分高、中、低账面市值比公司
    border_down, border_up = df['BM'].quantile([0.3, 0.7])
    border_down, border_up
    df['HML'] = df['BM'].map(lambda x: 'H' if x >= border_up else 'M')
    df['HML'] = df.apply(lambda row: 'L' if row['BM'] <= border_down else row['HML'], axis=1)

    # 组合划分为6组
    df_SL = df.query('(SB=="S") & (HML=="L")')
    df_SM = df.query('(SB=="S") & (HML=="M")')
    df_SH = df.query('(SB=="S") & (HML=="H")')
    df_BL = df.query('(SB=="B") & (HML=="L")')
    df_BM = df.query('(SB=="B") & (HML=="M")')
    df_BH = df.query('(SB=="B") & (HML=="H")')

    # 计算各组收益率
    R_SL = (df_SL['pct_chg'] * df_SL['circ_mv'] / 100).sum() / df_SL['circ_mv'].sum()
    R_SM = (df_SM['pct_chg'] * df_SM['circ_mv'] / 100).sum() / df_SM['circ_mv'].sum()
    R_SH = (df_SH['pct_chg'] * df_SH['circ_mv'] / 100).sum() / df_SH['circ_mv'].sum()
    R_BL = (df_BL['pct_chg'] * df_BL['circ_mv'] / 100).sum() / df_BL['circ_mv'].sum()
    R_BM = (df_BM['pct_chg'] * df_BM['circ_mv'] / 100).sum() / df_BM['circ_mv'].sum()
    R_BH = (df_BH['pct_chg'] * df_BH['circ_mv'] / 100).sum() / df_BH['circ_mv'].sum()

    # 计算SMB, HML并返回
    smb = (R_SL + R_SM + R_SH - R_BL - R_BM - R_BH) / 3
    hml = (R_SH + R_BH - R_SL - R_BL) / 2
    return smb, hml

# %%
start_date_str = '20180101'
end_date_str = '20180131'

# %%
data = []
df_cal = pro.trade_cal(start_date=start_date_str, end_date=end_date_str)
df_cal = df_cal.query('(exchange=="SSE") & (is_open==1)')
for date in df_cal.cal_date:
    df_daily = pro.daily(trade_date=date)
    df_basic = pro.daily_basic(trade_date=date)
    df = pd.merge(df_daily, df_basic, on='ts_code', how='inner')
    time.sleep(0.3)
    smb, hml = cal_smb_hml(df)
    data.append([date, smb, hml])
    #print(date)

# %%
df_tfm = pd.DataFrame(data, columns=['trade_date', 'SMB', 'HML'])
df_tfm['trade_date'] = pd.to_datetime(df_tfm.trade_date)
df_tfm = df_tfm.set_index('trade_date')
df_tfm.to_csv('df_three_factor_model.csv')
df_tfm.head()
# Out:
#                  SMB       HML
# trade_date
# 2018-01-02 -0.005300  0.002837
# 2018-01-03  0.001125 -0.002083
# 2018-01-04 -0.007970 -0.004825
# 2018-01-05  0.000439  0.006651
# 2018-01-08 -0.005685  0.002164

# %% [markdown]
# #### 2、挑选股票和基准指数
#
# 还是以这几只股票为例，不过这几只股票可能太有代表性，跟指数的波动形态比较接近，在大家自己练手的时候，推荐选择不同市值水平、PB水平的股票来测试，我们这里只讲解方法。

# %%
# 获取数据
wanke = pro.daily(ts_code='000002.SZ', start_date=start_date_str, end_date=end_date_str)
pingan = pro.daily(ts_code='601318.SH', start_date=start_date_str, end_date=end_date_str)
maotai = pro.daily(ts_code='600519.SH', start_date=start_date_str, end_date=end_date_str)
wanhua = pro.daily(ts_code='002415.SZ', start_date=start_date_str, end_date=end_date_str)
keda = pro.daily(ts_code='002230.SZ', start_date=start_date_str, end_date=end_date_str)
gzA = pro.index_daily(ts_code='399317.SZ', start_date=start_date_str, end_date=end_date_str)

# 仅保留收益率数据，且用日期作为index
# 然后按照日期排序（增序）
stock_list = [wanke, pingan, maotai, wanhua, keda, gzA]
for stock in stock_list:
    stock.index = pd.to_datetime(stock.trade_date)
df_stock = pd.concat([stock.pct_chg / 100 for stock in stock_list], axis=1)
df_stock.columns = ['wanke', 'pingan', 'maotai', 'wanhua', 'keda', 'gzA']
df_stock = df_stock.sort_index(ascending=True)
df_stock.head()
# Out:
#              wanke  pingan  maotai  wanhua    keda       gzA
# trade_date
# 2018-01-02  0.0483  0.0373  0.0091  0.0033  0.0242  0.012420
# 2018-01-03 -0.0071 -0.0223  0.0171  0.0130  0.0236  0.007357
# 2018-01-04  0.0244  0.0030  0.0296  0.0217  0.0152  0.003747
# 2018-01-05  0.0495 -0.0041  0.0018 -0.0178 -0.0157  0.001142
# 2018-01-08  0.0354 -0.0124  0.0186  0.0256 -0.0111  0.003742

# %% [markdown]
# #### 3、整合数据

# %%
df = pd.merge(df_stock, df_tfm, left_index=True, right_index=True, how='inner')
df = df.fillna(0)
rf = 1.032 ** (1/360) - 1
df = df - rf
df2 = df.copy()
df = df['20180101':]
df.head()
# Out:
#                wanke    pingan    maotai    wanhua      keda       gzA  \
# trade_date
# 2018-01-02  0.048212  0.037212  0.009012  0.003212  0.024112  0.012332
# 2018-01-03 -0.007188 -0.022388  0.017012  0.012912  0.023512  0.007269
# 2018-01-04  0.024312  0.002912  0.029512  0.021612  0.015112  0.003659
# 2018-01-05  0.049412 -0.004188  0.001712 -0.017888 -0.015788  0.001054
# 2018-01-08  0.035312 -0.012488  0.018512  0.025512 -0.011188  0.003654
#
#                  SMB       HML
# trade_date
# 2018-01-02 -0.005388  0.002750
# 2018-01-03  0.001037 -0.002171
# 2018-01-04 -0.008058 -0.004913
# 2018-01-05  0.000352  0.006564
# 2018-01-08 -0.005773  0.002077

# %%
sns.heatmap(df.corr(), cmap='bwr');

# %%
plt.figure(figsize=(10, 5))
for col in df.columns:
    plt.plot((df[col]+1).cumprod()-1, label=col)
plt.legend();

# %% [markdown]
# #### 4、回归分析

# %%
import statsmodels.api as sm

stock_names = {
    'wanke': '万科A',
    'pingan': '中国平安',
    'maotai': '贵州茅台',
    'wanhua': '万华化学',
    'keda': '科大讯飞'
}
for stock in ['wanke', 'pingan', 'maotai', 'wanhua', 'keda']:
    model = sm.OLS(df[stock], sm.add_constant(
        df[['gzA', 'SMB', 'HML']].values))
    result = model.fit()
    print(stock_names[stock] + '\n')
    print(result.summary())
    print('\n\n')
# Out:
# 万科A
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  wanke   R-squared:                       0.531
# Model:                            OLS   Adj. R-squared:                  0.453
# Method:                 Least Squares   F-statistic:                     6.794
# Date:                Sun, 03 Mar 2019   Prob (F-statistic):            0.00294
# Time:                        05:42:09   Log-Likelihood:                 53.131
# No. Observations:                  22   AIC:                            -98.26
# Df Residuals:                      18   BIC:                            -93.90
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0050      0.006     -0.816      0.425      -0.018       0.008
# x1             2.9190      0.838      3.485      0.003       1.159       4.679
# x2            -2.4156      0.653     -3.699      0.002      -3.788      -1.043
# x3             2.3815      1.017      2.341      0.031       0.245       4.518
# ==============================================================================
# Omnibus:                       11.768   Durbin-Watson:                   1.234
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):                9.984
# Skew:                           1.295   Prob(JB):                      0.00679
# Kurtosis:                       5.045   Cond. No.                         223.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# 中国平安
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 pingan   R-squared:                       0.422
# Model:                            OLS   Adj. R-squared:                  0.326
# Method:                 Least Squares   F-statistic:                     4.380
# Date:                Sun, 03 Mar 2019   Prob (F-statistic):             0.0176
# Time:                        05:42:09   Log-Likelihood:                 61.272
# No. Observations:                  22   AIC:                            -114.5
# Df Residuals:                      18   BIC:                            -110.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0023      0.004     -0.551      0.589      -0.011       0.007
# x1             0.4272      0.579      0.738      0.470      -0.788       1.643
# x2            -1.3518      0.451     -2.997      0.008      -2.299      -0.404
# x3            -0.6754      0.702     -0.961      0.349      -2.151       0.800
# ==============================================================================
# Omnibus:                        1.219   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.544   Jarque-Bera (JB):                0.954
# Skew:                           0.245   Prob(JB):                        0.621
# Kurtosis:                       2.105   Cond. No.                         223.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# 贵州茅台
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 maotai   R-squared:                       0.753
# Model:                            OLS   Adj. R-squared:                  0.712
# Method:                 Least Squares   F-statistic:                     18.27
# Date:                Sun, 03 Mar 2019   Prob (F-statistic):           1.07e-05
# Time:                        05:42:09   Log-Likelihood:                 69.180
# No. Observations:                  22   AIC:                            -130.4
# Df Residuals:                      18   BIC:                            -126.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.003      0.169      0.868      -0.006       0.007
# x1             0.9656      0.404      2.391      0.028       0.117       1.814
# x2            -1.0828      0.315     -3.439      0.003      -1.744      -0.421
# x3            -2.1166      0.490     -4.316      0.000      -3.147      -1.086
# ==============================================================================
# Omnibus:                        1.142   Durbin-Watson:                   1.750
# Prob(Omnibus):                  0.565   Jarque-Bera (JB):                0.903
# Skew:                          -0.216   Prob(JB):                        0.637
# Kurtosis:                       2.107   Cond. No.                         223.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# 万华化学
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 wanhua   R-squared:                       0.550
# Model:                            OLS   Adj. R-squared:                  0.475
# Method:                 Least Squares   F-statistic:                     7.321
# Date:                Sun, 03 Mar 2019   Prob (F-statistic):            0.00207
# Time:                        05:42:09   Log-Likelihood:                 65.928
# No. Observations:                  22   AIC:                            -123.9
# Df Residuals:                      18   BIC:                            -119.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0016      0.003     -0.473      0.642      -0.009       0.006
# x1             0.9020      0.468      1.926      0.070      -0.082       1.886
# x2            -0.7315      0.365     -2.004      0.060      -1.498       0.035
# x3            -1.4788      0.568     -2.601      0.018      -2.673      -0.284
# ==============================================================================
# Omnibus:                        0.015   Durbin-Watson:                   2.927
# Prob(Omnibus):                  0.992   Jarque-Bera (JB):                0.203
# Skew:                          -0.039   Prob(JB):                        0.904
# Kurtosis:                       2.536   Cond. No.                         223.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# 科大讯飞
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   keda   R-squared:                       0.325
# Model:                            OLS   Adj. R-squared:                  0.213
# Method:                 Least Squares   F-statistic:                     2.889
# Date:                Sun, 03 Mar 2019   Prob (F-statistic):             0.0640
# Time:                        05:42:09   Log-Likelihood:                 47.195
# No. Observations:                  22   AIC:                            -86.39
# Df Residuals:                      18   BIC:                            -82.03
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0053      0.008      0.658      0.519      -0.012       0.022
# x1             1.1744      1.097      1.070      0.299      -1.131       3.479
# x2             1.8191      0.855      2.127      0.048       0.022       3.616
# x3            -1.4582      1.332     -1.095      0.288      -4.257       1.340
# ==============================================================================
# Omnibus:                        6.046   Durbin-Watson:                   2.273
# Prob(Omnibus):                  0.049   Jarque-Bera (JB):                4.488
# Skew:                           0.534   Prob(JB):                        0.106
# Kurtosis:                       4.938   Cond. No.                         223.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
