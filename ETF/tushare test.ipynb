# %%
import tushare as ts
mytoken = '6feca07b866ea55bd6024aa5a8891d7bc11afd829d1386c8a2fc8d89'
# initial
pro = ts.pro_api(mytoken)

# %%
# get daily data
df = pro.daily(ts_code='000001.SZ', start_date='20190101', end_date='20190215')

# %%
df
# Out:
#       ts_code trade_date   open   high    low  close  pre_close  change  \
# 0   000001.SZ   20190215  11.23  11.23  10.90  10.95      11.25   -0.30
# 1   000001.SZ   20190214  11.30  11.33  11.19  11.25      11.38   -0.13
# 2   000001.SZ   20190213  11.19  11.41  11.12  11.38      11.19    0.19
# 3   000001.SZ   20190212  11.20  11.31  11.03  11.19      11.21   -0.02
# 4   000001.SZ   20190211  11.08  11.21  10.97  11.21      11.20    0.01
# 5   000001.SZ   20190201  11.20  11.25  10.96  11.20      11.10    0.10
# 6   000001.SZ   20190131  10.98  11.20  10.94  11.10      10.95    0.15
# 7   000001.SZ   20190130  10.95  11.18  10.86  10.95      11.00   -0.05
# 8   000001.SZ   20190129  10.96  11.07  10.77  11.00      10.94    0.06
# 9   000001.SZ   20190128  11.04  11.14  10.88  10.94      11.00   -0.06
# 10  000001.SZ   20190125  10.56  11.04  10.55  11.00      10.52    0.48
# 11  000001.SZ   20190124  10.40  10.55  10.37  10.52      10.35    0.17
# ...

# %%
import pandas as pd

# %%
# revert list
t = ['trade_date', 'open', 'high', 'low', 'close', 'vol']
ndf = df[t].sort_values(by='trade_date')
ndf['trade_date'] = pd.to_datetime(ndf['trade_date'])
ndf.set_index("trade_date", inplace=True)

# %%
ndf
# Out:
#              open   high    low  close         vol
# trade_date
# 2019-01-02   9.39   9.42   9.16   9.19   539386.32
# 2019-01-03   9.18   9.33   9.15   9.28   415537.95
# 2019-01-04   9.24   9.82   9.22   9.75  1481159.06
# 2019-01-07   9.84   9.85   9.63   9.74   865687.66
# 2019-01-08   9.73   9.74   9.62   9.66   402388.11
# 2019-01-09   9.74  10.08   9.70   9.94  1233486.36
# 2019-01-10   9.87  10.20   9.86  10.10  1071817.66
# 2019-01-11  10.11  10.22  10.05  10.20   696364.55
# 2019-01-14  10.22  10.25  10.07  10.11   500443.59
# 2019-01-15  10.11  10.28  10.09  10.24   542160.55
# 2019-01-16  10.24  10.50  10.23  10.48   977699.37
# 2019-01-17  10.54  10.57  10.17  10.25   882811.92
# 2019-01-18  10.34  10.49  10.28  10.43   738793.26
# 2019-01-21  10.34  10.47  10.32  10.34   659355.76
# 2019-01-22  10.34  10.44  10.26  10.28   424413.57
# 2019-01-23  10.29  10.47  10.29  10.35   537876.63
# 2019-01-24  10.40  10.55  10.37  10.52   679240.88
# ...

# %%
wdf = ndf.resample('W', loffset=pd.offsets.timedelta(days=-6)).mean().dropna()

# %%
wdf
# Out:
#               open       high        low      close            vol
# trade_date
# 2018-12-31   9.270   9.523333   9.176667   9.406667  812027.776667
# 2019-01-07   9.858  10.018000   9.772000   9.928000  853948.868000
# 2019-01-14  10.290  10.418000  10.168000  10.302000  728381.738000
# 2019-01-21  10.386  10.594000  10.358000  10.498000  881849.738000
# 2019-01-28  11.026  11.168000  10.882000  11.038000  884086.946000
# 2019-02-11  11.200  11.298000  11.042000  11.196000  973710.384000

# %%
# Index
df = pro.index_basic(market='SZSE', publisher='中证公司', category='规模指数')

# %%
df
# Out:
#      ts_code   name market publisher category base_date  base_point list_date
# 0  399300.SZ  沪深300   SZSE      中证公司     规模指数  20041231      1000.0  20050408
# 1  399902.SZ   中证流通   SZSE      中证公司     规模指数  20051230      1000.0  20060227
# 2  399903.SZ  中证100   SZSE      中证公司     规模指数  20051230      1000.0  20060529
# 3  399904.SZ  中证200   SZSE      中证公司     规模指数  20041231      1000.0  20070115
# 4  399905.SZ  中证500   SZSE      中证公司     规模指数  20041231      1000.0  20070115
# 5  399906.SZ  中证800   SZSE      中证公司     规模指数  20041231      1000.0  20070115
# 6  399907.SZ  中证700   SZSE      中证公司     规模指数  20041231      1000.0  20070115
# 7  399980.SZ   中证超大   SZSE      中证公司     规模指数  20041231      1000.0  20110510
# 8  399985.SZ   中证全指   SZSE      中证公司     规模指数  20041231      1000.0  20110802

# %%
df = pro.index_basic(market='SZSE', publisher='中证公司', category='一级行业指数')

# %%
df
# Out:
#       ts_code     name market publisher category base_date  base_point  \
# 0   399908.SZ  沪深300能源   SZSE      中证公司   一级行业指数  20041231      1000.0
# 1   399909.SZ  沪深300材料   SZSE      中证公司   一级行业指数  20041231      1000.0
# 2   399910.SZ  沪深300工业   SZSE      中证公司   一级行业指数  20041231      1000.0
# 3   399911.SZ  沪深300可选   SZSE      中证公司   一级行业指数  20041231      1000.0
# 4   399912.SZ  沪深300消费   SZSE      中证公司   一级行业指数  20041231      1000.0
# 5   399913.SZ  沪深300医药   SZSE      中证公司   一级行业指数  20041231      1000.0
# 6   399914.SZ  沪深300金融   SZSE      中证公司   一级行业指数  20041231      1000.0
# 7   399915.SZ  沪深300信息   SZSE      中证公司   一级行业指数  20041231      1000.0
# 8   399916.SZ  沪深300电信   SZSE      中证公司   一级行业指数  20041231      1000.0
# 9   399917.SZ  沪深300公用   SZSE      中证公司   一级行业指数  20041231      1000.0
# 10  399928.SZ     中证能源   SZSE      中证公司   一级行业指数  20041231      1000.0
# 11  399929.SZ     中证材料   SZSE      中证公司   一级行业指数  20041231      1000.0
# ...

# %%
df = pro.index_basic(market='CSI', category='一级行业指数')

# %%
df
# Out:
#         ts_code         name market publisher category base_date  base_point  \
# 0    000915.CSI      沪深300信息    CSI      中证公司   一级行业指数  20041231      1000.0
# 1    000916.CSI      沪深300电信    CSI      中证公司   一级行业指数  20041231      1000.0
# 2    000929.CSI         中证材料    CSI      中证公司   一级行业指数  20041231      1000.0
# 3    000930.CSI         中证工业    CSI      中证公司   一级行业指数  20041231      1000.0
# 4    000936.CSI         中证电信    CSI      中证公司   一级行业指数  20041231      1000.0
# 5    000937.CSI         中证公用    CSI      中证公司   一级行业指数  20041231      1000.0
# 6    000988.CSI         全指工业    CSI      中证公司   一级行业指数  20041231      1000.0
# 7    000994.CSI         全指电信    CSI      中证公司   一级行业指数  20041231      1000.0
# 8    000995.CSI         全指公用    CSI      中证公司   一级行业指数  20041231      1000.0
# 9    930606.CSI         中证钢铁    CSI      中证公司   一级行业指数  20081231      1000.0
# 10   h00908.CSI   沪深300能源全收益    CSI      中证公司   一级行业指数  20041231      1000.0
# ...

# %%
df[df['name'].str.contains('能源', na=False)]
# Out:
#         ts_code          name market publisher category base_date  base_point  \
# 10   h00908.CSI    沪深300能源全收益    CSI      中证公司   一级行业指数  20041231      1000.0
# 20   h00928.CSI     中证能源全收益指数    CSI      中证公司   一级行业指数  20041231      1000.0
# 30   h00986.CSI       全指能源全收益    CSI      中证公司   一级行业指数  20041231      1000.0
# 69   h20375.CSI     CN能源综合(全)    CSI      中证公司   一级行业指数  20041231      1000.0
# 79   h20386.CSI  CN能源综合(全)USD    CSI      中证公司   一级行业指数  20041231      1000.0
# 130  h30375.CSI        CN能源综合    CSI      中证公司   一级行业指数  20041231      1000.0
# 140  h30386.CSI   CN能源综合(USD)    CSI      中证公司   一级行业指数  20041231      1000.0
# 150  h30439.CSI        1000能源    CSI      中证公司   一级行业指数  20041231      1000.0
# 160  n00908.CSI    沪深300能源净收益    CSI      中证公司   一级行业指数  20041231      1000.0
#
#     list_date
# 10   20070702
# 20   20090703
# 30   20110802
# 69   20140731
# 79   20140731
# 130  20140731
# 140  20140731
# 150  20141017
# 160  20130208

# %%
# Index Daily Price
df = pro.index_daily(ts_code='000991.SH', start_date='20190101', end_date='20190223')

# %%
df
# Out:
#       ts_code trade_date      close       open       high        low  \
# 0   000991.SH   20190222  8178.5844  8056.0440  8178.5844  8002.6617
# 1   000991.SH   20190221  8061.8369  8097.4598  8186.9287  8038.9087
# 2   000991.SH   20190220  8095.0564  8142.9142  8146.5746  8006.8379
# 3   000991.SH   20190219  8161.5892  8244.1605  8275.5589  8088.8641
# 4   000991.SH   20190218  8223.4755  7982.2856  8223.4755  7982.2856
# 5   000991.SH   20190215  7925.2204  7983.6595  8008.2113  7909.1061
# 6   000991.SH   20190214  7995.1734  7944.5993  8026.7848  7907.2276
# 7   000991.SH   20190213  7951.2003  7862.6710  7975.6725  7817.9480
# 8   000991.SH   20190212  7844.2004  7667.3761  7881.0941  7665.3955
# 9   000991.SH   20190211  7650.8673  7455.0512  7655.5347  7455.0512
# 10  000991.SH   20190201  7469.1361  7262.7058  7473.5074  7262.2051
# 11  000991.SH   20190131  7225.3715  7250.7236  7295.2406  7185.5181
# 12  000991.SH   20190130  7241.6029  7282.5286  7336.0159  7238.8397
# ...

# %%
# Index Weight
df = pro.index_weight(index_code='399300.SZ')

# %%
df
# Out:
#      index_code   con_code trade_date  weight
# 0     399300.SZ  601138.SH   20190201  0.1388
# 1     399300.SZ  001965.SZ   20190201  0.0455
# 2     399300.SZ  603259.SH   20190201  0.0799
# 3     399300.SZ  601066.SH   20190201  0.0536
# 4     399300.SZ  002925.SZ   20190201  0.0450
# 5     399300.SZ  600025.SH   20190201  0.0586
# 6     399300.SZ  603260.SH   20190201  0.0351
# 7     399300.SZ  001979.SZ   20190201  0.4451
# 8     399300.SZ  601155.SH   20190201  0.2618
# 9     399300.SZ  601108.SH   20190201  0.0288
# 10    399300.SZ  601228.SH   20190201  0.0739
# 11    399300.SZ  603833.SH   20190201  0.1109
# 12    399300.SZ  601881.SH   20190201  0.0993
# 13    399300.SZ  300408.SZ   20190201  0.1798
# 14    399300.SZ  603858.SH   20190201  0.1070
# 15    399300.SZ  600977.SH   20190201  0.1159
# 16    399300.SZ  601611.SH   20190201  0.0536
# 17    399300.SZ  601212.SH   20190201  0.0248
# 18    399300.SZ  603799.SH   20190201  0.1330
# ...

# %%
# Index Daily Ratio
df = pro.index_dailybasic(ts_code='', trade_date='20190219', fields='ts_code,trade_date,turnover_rate,pe,pe_ttm,pb')

# %%
df
# Out:
#       ts_code trade_date  turnover_rate     pe  pe_ttm    pb
# 0   000001.SH   20190219           0.86  13.21   12.23  1.36
# 1   000005.SH   20190219           2.39  15.77   14.99  1.46
# 2   000006.SH   20190219           0.83   9.53    8.40  1.36
# 3   000016.SH   20190219           0.24  10.24    9.43  1.17
# 4   000300.SH   20190219           0.66  12.40   11.50  1.39
# 5   000905.SH   20190219           1.87  19.89   18.18  1.73
# 6   399001.SZ   20190219           2.37  20.67   18.88  2.31
# 7   399005.SZ   20190219           2.41  24.54   22.17  3.07
# 8   399006.SZ   20190219           2.81  35.78   31.66  3.94
# 9   399016.SZ   20190219           3.68  22.69   22.17  3.19
# 10  399300.SZ   20190219           0.66  12.40   11.50  1.39
# 11  399905.SZ   20190219           1.87  19.89   18.18  1.73

# %%
df = pro.daily_basic(ts_code='', trade_date='20190219', fields='ts_code,trade_date,circ_mv,total_mv,pe,pb')

# %%
df
# Out:
#         ts_code trade_date        pe       pb      total_mv       circ_mv
# 0     603238.SH   20190219   43.7206   2.7879  2.254800e+05  5.637000e+04
# 1     603386.SH   20190219   50.0021   5.0517  3.281268e+05  9.215355e+04
# 2     603429.SH   20190219   49.5034   8.4600  4.908512e+05  2.515612e+05
# 3     603897.SH   20190219   22.9457   2.4218  4.071088e+05  1.017772e+05
# 4     601158.SH   20190219   13.6551   1.9986  2.822400e+06  2.822400e+06
# 5     600539.SH   20190219       NaN   3.4766  1.490400e+05  1.490400e+05
# 6     000021.SZ   20190219   19.6239   1.7188  1.062249e+06  1.060854e+06
# 7     603360.SH   20190219   28.9510   3.8058  2.902812e+05  1.219265e+05
# 8     000875.SZ   20190219       NaN   0.7824  5.730658e+05  5.218006e+05
# 9     002663.SZ   20190219   32.9891   0.9608  5.010534e+05  3.487084e+05
# 10    002572.SZ   20190219   18.8907   3.6184  1.712956e+06  1.183668e+06
# 11    300153.SZ   20190219   86.2891   2.6038  2.499200e+05  2.496056e+05
# ...

# %%
import urllib
outfilename = "test.xls"
url_of_file = "http://www.csindex.com.cn/uploads/file/autofile/closeweight/000908closeweight.xls"
urllib.request.urlretrieve(url_of_file, outfilename)
# Out:
# ('test.xls', <http.client.HTTPMessage at 0x7f03bd6a1978>)

# %%
df = pd.read_excel("test.xls")

# %%
list(df)
# Out:
# ['日期Date',
#  '指数代码Index Code',
#  '指数名称Index Name',
#  '指数英文名称Index Name(Eng.)',
#  '成分券代码Constituent Code',
#  '成分券名称Constituent Name',
#  '成分券英文名称Constituent Name(Eng.)',
#  '交易所Exchange',
#  '权重(%)Weight(%)']

# %%
df[['成分券代码Constituent Code', '权重(%)Weight(%)']]
# Out:
#     成分券代码Constituent Code  权重(%)Weight(%)
# 0                  600028           25.99
# 1                  600157            3.72
# 2                  600188            2.89
# 3                  600339            2.30
# 4                  600583            4.22
# 5                  600688            4.20
# 6                  601088           14.44
# 7                  601225           12.28
# 8                  601808            1.87
# 9                  601857           21.81
# 10                 601898            3.13
# 11                    983            3.15

# %%
df = pro.daily_basic(ts_code='600028.SH', trade_date='20190219', fields='ts_code,trade_date,turnover_rate,volume_ratio,pe,pb')

# %%
df
# Out:
# Empty DataFrame
# Columns: [ts_code, trade_date, turnover_rate, volume_ratio, pe, pb]
# Index: []

# %%
# Fund Basic
df = pro.fund_basic(market='E') #E: 场内 O:场外

# %%
df
# Out:
#         ts_code               name management custodian fund_type found_date  \
# 0     511270.SH  海富通上证10年期地方政府债ETF      海富通基金      中国银行       债券型   20181012
# 1     512850.SH        中信建投北京50ETF     中信建投基金      招商银行       股票型   20180927
# 2     168601.SZ         汇安裕阳三年定期开放       汇安基金    中国光大银行       混合型   20180927
# 3     512860.SH    华安MSCI中国A股国际ETF       华安基金    中国农业银行       股票型   20180927
# 4     159960.SZ               恒生国企     平安大华基金      中国银行       股票型   20180921
# 5     501062.SH             南方瑞合三年       南方基金    中国建设银行       混合型   20180906
# 6     510600.SH             沪50ETF     申万菱信基金    中国工商银行       股票型   20180903
# 7     501061.SH             金选300C       中金基金    中国建设银行       股票型   20180830
# 8     501060.SH             金选300A       中金基金    中国建设银行       股票型   20180830
# 9     166802.SZ              浙商300       浙商基金      华夏银行       股票型   20180820
# 10    160726.SZ               嘉实瑞享       嘉实基金      中国银行       混合型   20180803
# ...

# %%
df = pro.fund_basic(market='E')

# %%
df.head()
# Out:
#      ts_code   name management custodian fund_type found_date due_date  \
# 0  501058.SH   新能车C      汇添富基金    中国工商银行       股票型   20180523     None
# 1  501057.SH   新能源车      汇添富基金    中国工商银行       股票型   20180523     None
# 2  510380.SH  国寿300     国寿安保基金    中国农业银行       股票型   20180119     None
# 3  512980.SH  传媒ETF       广发基金    中国工商银行       股票型   20171227     None
# 4  510390.SH  平安300     平安大华基金    中国工商银行       股票型   20171225     None
#
#   list_date issue_date delist_date  ...    min_amount  exp_return  \
# 0  20180620   20180507        None  ...         0.001        None
# 1  20180620   20180507        None  ...         0.001        None
# 2  20180207   20171013        None  ...         0.100        None
# 3  20180119   20171127        None  ...         0.100        None
# 4  20180126   20171204        None  ...         0.100        None
#
#                                benchmark  status  invest_type    type trustee  \
# ...

# %%
df[df['benchmark'].str.contains('可选', na=False)]
# Out:
#        ts_code  name management custodian fund_type found_date due_date  \
# 326  159936.SZ  可选消费       广发基金      中国银行       股票型   20140603     None
#
#     list_date issue_date delist_date  ...    min_amount  exp_return  \
# 326  20140625   20140505        None  ...           0.1        None
#
#       benchmark  status  invest_type    type trustee purc_startdate  \
# 326  中证全指可选消费指数       L        被动指数型  契约型开放式    None       20140625
#
#     redm_startdate market
# 326       20140625      E
#
# [1 rows x 25 columns]

# %%
df = pro.fund_nav(ts_code='159936.SZ')

# %%
df
# Out:
#         ts_code  ann_date  end_date  unit_nav  accum_nav accum_div  \
# 0     159936.SZ  20190223  20190222    1.2309     1.2309      None
# 1     159936.SZ  20190221  20190220    1.2174     1.2174      None
# 2     159936.SZ  20190220  20190219    1.2132     1.2132      None
# 3     159936.SZ  20190219  20190218    1.2127     1.2127      None
# 4     159936.SZ  20190216  20190215    1.1769     1.1769      None
# 5     159936.SZ  20190214  20190213    1.1916     1.1916      None
# 6     159936.SZ  20190213  20190212    1.1727     1.1727      None
# 7     159936.SZ  20190212  20190211    1.1597     1.1597      None
# 8     159936.SZ  20190202  20190201    1.1300     1.1300      None
# 9     159936.SZ  20190201  20190131    1.1066     1.1066      None
# 10    159936.SZ  20190131  20190130    1.1103     1.1103      None
# 11    159936.SZ  20190126  20190125    1.1384     1.1384      None
# 12    159936.SZ  20190125  20190124    1.1351     1.1351      None
# ...

# %%
# Fund Mgt Companies
df = pro.fund_company()

# %%
df
# Out:
#                       name   shortname province   city  \
# 0           北京广能投资基金管理有限公司        广能基金       北京    北京市
# 1               平安银行股份有限公司        平安银行       广东    深圳市
# 2               宏源证券股份有限公司        宏源证券       新疆  乌鲁木齐市
# 3            陕西省国际信托股份有限公司         陕国投       陕西    西安市
# 4               东北证券股份有限公司        东北证券       吉林    长春市
# 5               国元证券股份有限公司        国元证券       安徽    合肥市
# 6               国海证券股份有限公司        国海证券       广西    桂林市
# 7               广发证券股份有限公司        广发证券       广东    广州市
# 8               长江证券股份有限公司        长江证券       湖北    武汉市
# 9           上海浦东发展银行股份有限公司        浦发银行       上海    上海市
# 10              东方金钰股份有限公司        东方金钰       湖北    鄂州市
# 11              国金证券股份有限公司        国金证券       四川    成都市
# 12            绿地控股集团股份有限公司        绿地控股       上海    上海市
# 13              安信信托股份有限公司        安信信托       上海    上海市
# 14              海通证券股份有限公司        海通证券       上海    上海市
# 15            中国民生银行股份有限公司      中国民生银行       北京    北京市
# ...

# %%
# Fund NAV
df = pro.fund_nav(ts_code='165509.SZ')

# %%
df
# Out:
#         ts_code  ann_date  end_date  unit_nav  accum_nav accum_div  \
# 0     165509.SZ  20190219  20190218     1.135      1.624      None
# 1     165509.SZ  20190216  20190215     1.131      1.620      None
# 2     165509.SZ  20190214  20190213     1.130      1.619      None
# 3     165509.SZ  20190213  20190212     1.130      1.619      None
# 4     165509.SZ  20190212  20190211     1.129      1.618      None
# 5     165509.SZ  20190202  20190201     1.126      1.615      None
# 6     165509.SZ  20190201  20190131     1.123      1.612      None
# 7     165509.SZ  20190131  20190130     1.123      1.612      None
# 8     165509.SZ  20190130  20190129     1.122      1.611      None
# 9     165509.SZ  20190129  20190128     1.122      1.611      None
# 10    165509.SZ  20190126  20190125     1.123      1.612      None
# 11    165509.SZ  20190125  20190124     1.122      1.611      None
# 12    165509.SZ  20190124  20190123     1.121      1.610      None
# ...

# %%
df = pro.query( 'income',  ts_code='000002.SZ', start_date='20170101', end_date='20190220', fields='ts_code,ann_date,f_ann_date,end_date,report_type,comp_type,total_profit,ebit,ebitda')

# %%
df
# Out:
#      ts_code  ann_date f_ann_date  end_date report_type comp_type  \
# 0  000002.SZ  20181026   20181026  20180930           1         1
# 1  000002.SZ  20180821   20180821  20180630           1         1
# 2  000002.SZ  20180426   20180426  20180331           1         1
# 3  000002.SZ  20180327   20180327  20171231           1         1
# 4  000002.SZ  20171027   20171027  20170930           1         1
# 5  000002.SZ  20170825   20170825  20170630           1         1
# 6  000002.SZ  20170428   20170428  20170331           1         1
#
#    total_profit          ebit        ebitda
# 0  3.166211e+10  3.705694e+10           NaN
# 1  1.966784e+10  2.184139e+10  2.311415e+10
# 2  2.999302e+09  4.487114e+09           NaN
# 3  5.114195e+10  4.672265e+10  4.865168e+10
# 4  2.090159e+10  1.872425e+10           NaN
# 5  1.382691e+10  1.286009e+10  1.376231e+10
# 6  1.571531e+09           NaN           NaN
